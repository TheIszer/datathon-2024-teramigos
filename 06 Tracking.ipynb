# %%
import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

import datetime

# %%
flights = pd.read_csv("/work/Habemus_Dataset.csv", sep=",")
flights.head()
# Out:
#                           Flight_ID Aeronave DepartureStation ArrivalStation  \
# 0  ab954014077430bd842cfa305a55c0f8   XA-VBY               AT             AZ
# 1  efd86c996035dacdca7a0ccb2560dda1   XA-VIX               BM             AV
# 2  dd0fad3248951d2f71d63e6279aeaa4b   XA-VBW               AW             AS
# 3  d0987ee648eea254063bfe2b39571b67   XA-VAP               BA             AB
# 4  3b5df8805161ea827d2f2e4298c38e06   XA-VBY               AJ             AR
#
#       Destination_Type          Origin_Type                  STD  \
# 0    Ciudad Fronteriza     Ciudad Principal  2023-10-19 11:40:00
# 1  MX Amigos y Familia    Ciudad Fronteriza  2023-07-03 00:55:00
# 2  MX Amigos y Familia     Ciudad Principal  2023-06-26 15:15:00
# 3                Playa     Ciudad Principal  2023-02-10 08:40:00
# 4                Playa  MX Amigos y Familia  2023-09-07 17:10:00
#
#                    STA  Capacity  Passengers  ...  Quantity_Sopas  \
# 0  2023-10-19 14:25:00       240       229.0  ...             0.0
# 1  2023-07-03 04:55:00       186       197.0  ...             2.0
# 2  2023-06-26 15:55:00       220       200.0  ...             0.0
# 3  2023-02-10 09:50:00       186       162.0  ...             0.0
# 4  2023-09-07 18:05:00       240       183.0  ...             0.0
#
#    TotalSales_Alimentos Charter  TotalSales_Bebidas Calientes  \
# 0                           0.0                          45.0
# 1                           0.0                          40.0
# 2                           0.0                           0.0
# 3                           0.0                         120.0
# 4                           0.0                           0.0
#
#    TotalSales_Botanas  TotalSales_Galletas  TotalSales_Lacteos  \
# 0               541.0                 45.0                 0.0
# 1               143.0                  0.0                 0.0
# 2                 0.0                  0.0                 0.0
# 3               188.0                168.0                42.0
# 4                 0.0                  0.0                 0.0
#
#    TotalSales_Licores  TotalSales_Perecederos  TotalSales_Refrescos  \
# 0               659.0                   460.0                 816.0
# 1               350.0                   110.0                 270.0
# 2                 0.0                     0.0                   0.0
# 3                 0.0                   330.0                 306.0
# 4               360.0                     0.0                   0.0
#
#    TotalSales_Sopas
# 0               0.0
# 1              90.0
# 2               0.0
# 3               0.0
# 4               0.0
#
# [5 rows x 37 columns]

# %%
# Single airplane
airplane = "XA-VBY"
allFlights = flights[flights["Aeronave"] == "XA-VBY"]
allFlights = allFlights.sort_values(by=['STD'])
allFlights
# Out:
#                                Flight_ID Aeronave DepartureStation  \
# 104187  fdcacd5a4581b780696c474f034a7387   XA-VBY               AT
# 16660   5286729aa26a85894d3eefa3c6d084c5   XA-VBY               BM
# 112920  16439893e3e933600b81c27d87457c8c   XA-VBY               AK
# 59053   7b7feddbebe67f019a89d00ea61f0434   XA-VBY               BM
# 64340   dbad121851fc9a2e3969fa5260156d46   XA-VBY               AT
# ...                                  ...      ...              ...
# 77863   00fa03ce99cf59ab77df935b7c7a2ac0   XA-VBY               BJ
# 13946   7d958a62ef70cdfcc30dc30bce256c5e   XA-VBY               AW
# 70988   009e196090e8c985cccd1fac809984c8   XA-VBY               AK
# 102867  f13af7da9870e3b0bb3156ba927ceecf   XA-VBY               AW
# 71496   b73b83b3e7e0544d2bc556210c4e8842   XA-VBY               BL
#
#        ArrivalStation   Destination_Type          Origin_Type  \
# 104187             BM  Ciudad Fronteriza     Ciudad Principal
# 16660              AK              Playa    Ciudad Fronteriza
# 112920             BM  Ciudad Fronteriza                Playa
# 59053              AT   Ciudad Principal    Ciudad Fronteriza
# 64340              AU         Ecoturismo     Ciudad Principal
# ...               ...                ...                  ...
# 77863              AW   Ciudad Principal  MX Amigos y Familia
# 13946              AK              Playa     Ciudad Principal
# 70988              AW   Ciudad Principal                Playa
# 102867             BL         Ecoturismo     Ciudad Principal
# 71496              AW   Ciudad Principal           Ecoturismo
#
#                         STD                  STA  Capacity  Passengers  ...  \
# 104187  2023-01-02 05:00:00  2023-01-02 06:45:00       240       253.0  ...
# 16660   2023-01-02 07:35:00  2023-01-02 15:00:00       240       163.0  ...
# 112920  2023-01-02 15:55:00  2023-01-02 18:00:00       240       247.0  ...
# 59053   2023-01-02 18:45:00  2023-01-03 00:10:00       240       226.0  ...
# 64340   2023-01-03 00:55:00  2023-01-03 02:45:00       240       181.0  ...
# ...                     ...                  ...       ...         ...  ...
# 77863   2023-12-30 16:45:00  2023-12-30 17:55:00       240       145.0  ...
# 13946   2023-12-31 07:40:00  2023-12-31 11:05:00       240       172.0  ...
# 70988   2023-12-31 11:50:00  2023-12-31 13:25:00       240       125.0  ...
# 102867  2023-12-31 14:20:00  2023-12-31 16:30:00       240       173.0  ...
# 71496   2023-12-31 17:15:00  2023-12-31 19:25:00       240       134.0  ...
#
#         Quantity_Sopas  TotalSales_Alimentos Charter  \
# 104187             2.0                           0.0
# 16660             24.0                           0.0
# 112920             9.0                           0.0
# 59053              2.0                           0.0
# 64340              0.0                           0.0
# ...                ...                           ...
# 77863              0.0                           0.0
# 13946              0.0                           0.0
# 70988              2.0                           0.0
# 102867             3.0                           0.0
# 71496             10.0                           0.0
#
#         TotalSales_Bebidas Calientes  TotalSales_Botanas  TotalSales_Galletas  \
# 104187                         160.0               413.0                210.0
# 16660                          120.0              1869.0                228.0
# 112920                         640.0              3413.0                690.0
# 59053                          120.0              1492.0                312.0
# 64340                           40.0                90.0                  0.0
# ...                              ...                 ...                  ...
# 77863                            0.0                 0.0                  0.0
# 13946                            0.0                 0.0                  0.0
# 70988                           90.0               392.0                150.0
# 102867                          45.0              1221.0                 90.0
# 71496                            0.0              1331.0                222.0
#
#         TotalSales_Lacteos  TotalSales_Licores  TotalSales_Perecederos  \
# 104187                 0.0                 0.0                   110.0
# 16660                 42.0              1410.0                  1650.0
# 112920               210.0              1602.0                  2970.0
# 59053                168.0               817.0                  1320.0
# 64340                  0.0                 0.0                   220.0
# ...                    ...                 ...                     ...
# 77863                  0.0                 0.0                     0.0
# 13946                  0.0                 0.0                     0.0
# 70988                  0.0               144.0                   345.0
# 102867                 0.0              1257.0                   460.0
# 71496                 42.0               144.0                   805.0
#
#         TotalSales_Refrescos  TotalSales_Sopas
# 104187                 756.0              90.0
# 16660                 2481.0            1080.0
# 112920                4761.0             405.0
# 59053                 1476.0              90.0
# 64340                  225.0               0.0
# ...                      ...               ...
# 77863                    0.0               0.0
# 13946                    0.0               0.0
# 70988                  840.0              90.0
# 102867                1104.0             135.0
# 71496                 1272.0             450.0
#
# [2101 rows x 37 columns]

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=25b1adb0-2b47-474f-a7b7-c06d723a95f4' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
